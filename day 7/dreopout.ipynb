# %%
from tensorflow import keras
from tensorflow.keras.layers import Input, Dense, Reshape, Flatten
import tensorflow as tf
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.keras.optimizers import Adam,Adadelta

# %%
(x_train,y_train),(x_test,y_test)=keras.datasets.mnist.load_data()

# %%
x_train=x_train/255

# %%
x_test=x_test/255

# %%
x_train_flatten=x_train.reshape(len(x_train),28*28)

# %%
x_test_flatten=x_test.reshape(len(x_test),28*28)

# %%
model=keras.Sequential([
    keras.layers.Dense(50, activation='relu', input_shape=(784,)),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(10, activation='softmax'),
])
model.compile(optimizer=Adam(learning_rate=0.05), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
df=model.fit(x_train_flatten,y_train,epochs=20,batch_size=1000,validation_data=(x_test_flatten,y_test))
# Out:
# Epoch 1/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.6857 - loss: 0.9930 - val_accuracy: 0.9276 - val_loss: 0.2469
# Epoch 2/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8930 - loss: 0.3397 - val_accuracy: 0.9451 - val_loss: 0.1917
# Epoch 3/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9105 - loss: 0.2764 - val_accuracy: 0.9517 - val_loss: 0.1727
# Epoch 4/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9200 - loss: 0.2528 - val_accuracy: 0.9509 - val_loss: 0.1662
# Epoch 5/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9249 - loss: 0.2420 - val_accuracy: 0.9532 - val_loss: 0.1622
# Epoch 6/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.9287 - loss: 0.2294 - val_accuracy: 0.9528 - val_loss: 0.1633
# Epoch 7/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9297 - loss: 0.2203 - val_accuracy: 0.9568 - val_loss: 0.1534
# Epoch 8/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9350 - loss: 0.2050 - val_accuracy: 0.9569 - val_loss: 0.1556
# Epoch 9/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9341 - loss: 0.2101 - val_accuracy: 0.9547 - val_loss: 0.1703
# Epoch 10/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9364 - loss: 0.2024 - val_accuracy: 0.9568 - val_loss: 0.1759
# Epoch 11/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9352 - loss: 0.2032 - val_accuracy: 0.9584 - val_loss: 0.1586
# Epoch 12/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9388 - loss: 0.1962 - val_accuracy: 0.9561 - val_loss: 0.1659
# Epoch 13/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9380 - loss: 0.1991 - val_accuracy: 0.9519 - val_loss: 0.1820
# Epoch 14/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9398 - loss: 0.1937 - val_accuracy: 0.9573 - val_loss: 0.1742
# Epoch 15/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9402 - loss: 0.1965 - val_accuracy: 0.9619 - val_loss: 0.1656
# Epoch 16/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9434 - loss: 0.1854 - val_accuracy: 0.9596 - val_loss: 0.1686
# Epoch 17/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9424 - loss: 0.1856 - val_accuracy: 0.9556 - val_loss: 0.1791
# Epoch 18/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9453 - loss: 0.1775 - val_accuracy: 0.9574 - val_loss: 0.1783
# Epoch 19/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9437 - loss: 0.1794 - val_accuracy: 0.9552 - val_loss: 0.1800
# Epoch 20/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9440 - loss: 0.1852 - val_accuracy: 0.9560 - val_loss: 0.1803

# %%
plt.plot(df.history['loss'])
plt.plot(df.history['val_loss'])
plt.title('Training and validation loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['loss', 'val_loss'], loc='upper left')
plt.show()

# %%
plt.plot(df.history['accuracy'])
plt.plot(df.history['val_accuracy'])
plt.title('Training and validation loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['accuracy', 'val_accuracy'], loc='upper left')
plt.show()
